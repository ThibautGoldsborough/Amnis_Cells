# %%
#Import required packages
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

DATASETS=["BoneMarrow_sample1","Retina_1_2","Colon","Choroid","Retina_0_0"]

# %%
DATASET="BoneMarrow_sample1"
Ch7=[]
Ch2=[]
Ch3=[]
Ch11=[]
from Helper_functions import log_pol_scale,log_pol

basepath = r"C:\Users\Thibaut Goldsborough\Documents\Seth_BoneMarrow\Data\\" +DATASET
outpath = basepath + "\\Outputs"

df=pd.read_csv(outpath+"\\cell_info.csv")

Ch7+=list(df["Intensity_MC_Ch07"].to_numpy())
labels=log_pol(np.array(Ch7),slope=3,c=150000)
df["Scaled_Ch07"]=labels

Ch2+=list(df["Intensity_MC_Ch02"].to_numpy())
labels=np.log(1+log_pol(np.array(Ch2),slope=3,c=50000))*3
df["Scaled_Ch02"]=labels

Ch3+=list(df["Intensity_MC_Ch03"].to_numpy())
labels=np.log(1+log_pol(np.array(Ch3),slope=5,c=30000))
df["Scaled_Ch03"]=labels

Ch11+=list(df["Intensity_MC_Ch11"].to_numpy())
labels=log_pol(np.array(Ch11),slope=3,c=5000)
df["Scaled_Ch11"]=labels

df.to_csv(outpath+"\\"+""+"cell_info1.csv",index=False)

# %%
DATASET="Retina_1_2"
Ch7=[]
Ch10=[]
Ch11=[]
from Helper_functions import log_pol_scale,log_pol

basepath = r"C:\Users\Thibaut Goldsborough\Documents\Seth_BoneMarrow\Data\\" +DATASET
outpath = basepath + "\\Outputs"

df=pd.read_csv(outpath+"\\cell_info.csv")

Ch7+=list(df["Intensity_MC_Ch07"].to_numpy())
labels7=log_pol(np.array(Ch7),slope=3,c=300000)
df["Scaled_Ch07"]=labels7

Ch10+=list(df["Intensity_MC_Ch10"].to_numpy())
labels=log_pol(np.array(Ch10),slope=3,c=4500)
df["Scaled_Ch10"]=labels

Ch11+=list(df["Intensity_MC_Ch11"].to_numpy())
labels11=log_pol(np.array(Ch11),slope=3,c=1000)
df["Scaled_Ch11"]=labels11


df["Scaled_Ch11_Comp"]=labels11-labels7

df.to_csv(outpath+"\\"+""+"cell_info1.csv",index=False)

# %%
plt.scatter(df["Scaled_Ch07"],df["Scaled_Ch11_Comp"],s=0.1)

# %%
plt.hist(df["Scaled_Ch07"],bins=100);

# %%
DATASET="Colon"
Ch7=[]

from Helper_functions import log_pol_scale,log_pol

basepath = r"C:\Users\Thibaut Goldsborough\Documents\Seth_BoneMarrow\Data\\" +DATASET
outpath = basepath + "\\Outputs"

df=pd.read_csv(outpath+"\\cell_info.csv")

Ch7+=list(df["Intensity_MC_Ch07"].to_numpy())
labels=log_pol(np.array(Ch7),slope=3,c=10000)/4
df["Scaled_Ch07"]=labels

df.to_csv(outpath+"\\"+""+"cell_info1.csv",index=False)

# %%
DATASET="Choroid"
Ch7=[]

from Helper_functions import log_pol_scale,log_pol

basepath = r"C:\Users\Thibaut Goldsborough\Documents\Seth_BoneMarrow\Data\\" +DATASET
outpath = basepath + "\\Outputs"

df=pd.read_csv(outpath+"\\cell_info.csv")

Ch7+=list(df["Intensity_MC_Ch07"].to_numpy())
labels=log_pol(np.array(Ch7),slope=3,c=10000)/4
df["Scaled_Ch07"]=labels

df.to_csv(outpath+"\\"+""+"cell_info1.csv",index=False)

# %%
DATASET="Retina_0_0"
Ch7=[]

from Helper_functions import log_pol_scale,log_pol

basepath = r"C:\Users\Thibaut Goldsborough\Documents\Seth_BoneMarrow\Data\\" +DATASET
outpath = basepath + "\\Outputs"

df=pd.read_csv(outpath+"\\cell_info.csv")

Ch7+=list(df["Intensity_MC_Ch07"].to_numpy())
labels=log_pol(np.array(Ch7),slope=3,c=225000)
df["Scaled_Ch07"]=labels

df.to_csv(outpath+"\\"+""+"cell_info1.csv",index=False)

# %%
DATASET="Colon"
Ch7=[]

from Helper_functions import log_pol_scale,log_pol

basepath = r"C:\Users\Thibaut Goldsborough\Documents\Seth_BoneMarrow\Data\\" +DATASET
outpath = basepath + "\\Outputs"

df=pd.read_csv(outpath+"\\cell_info.csv")
Ch11=list(df["Intensity_MC_Ch07"].to_numpy())

#df=pd.read_csv(outpath+"\\cell_info1.csv")
#Ch7=df["Scaled_Ch07"].to_numpy()

Ch11_s=np.sort(Ch11)
plt.hist(Ch11_s[:-1000],bins=300);
#plt.xlim(-1,10000)
plt.show()
labels2=log_pol(np.array(Ch11),slope=3,c=10000)/4


# plt.hist(labels2/(Ch7+1),bins=400);
# plt.show()
plt.hist(labels2,bins=400);
# #plt.xlim(-1,6)

# #plt.axvline(x=1)
#plt.yscale('log')

# %%
cones1=[7868, 53328, 8687, 7995, 9260, 6729, 8915, 52667, 54913, 7653, 9375, 51527, 52213, 50763, 49827, 52724, 9536, 7142, 55078, 54239, 55344, 5515, 52102, 5603, 55535, 730, 8570, 5234, 6892, 784, 7346, 7347, 9290, 53041, 53200, 49940, 52738, 7048, 5737, 841, 6597, 7316, 55102, 5508]
cones2=[6491, 8093, 53796, 7800, 7261, 5622, 939, 6541, 52091, 7346, 49940, 7868, 54170, 8915, 53041, 52738, 863, 5978, 8199, 7048, 7316]
cones=cones1+cones2
plt.rc('text', usetex = False)
plt.rc('font', family = 'serif')
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize']=20
plt.rcParams['ytick.labelsize']=20
plt.rcParams['axes.titlesize'] =20
plt.rc('font', size=15)  

DATASET="Retina_1_2"
basepath = r"C:\Users\Thibaut Goldsborough\Documents\Seth_BoneMarrow\Data\\" +DATASET
outpath = basepath + "\\Outputs"

df=pd.read_csv(outpath+"\\cell_info1.csv")

Ch7=df["Scaled_Ch07"].to_numpy()#[:,None]
Ch10=df["Scaled_Ch10"].to_numpy()#[:,None]
Ch11=df["Scaled_Ch11"].to_numpy()#[:,None]
names=df["Cell_ID"].to_numpy()
cones_ID=np.array([np.where(namesdf==i)[0][0] for i in cones])

from Helper_functions import density_scatter
from scipy.stats import spearmanr
from matplotlib import cm
from matplotlib.colors import Normalize 
from scipy.interpolate import interpn

def density_scatter( x , y, sort = True, bins = 20 )   :
    data , x_e, y_e = np.histogram2d( x, y, bins = bins, density = True )
    z = interpn( ( 0.5*(x_e[1:] + x_e[:-1]) , 0.5*(y_e[1:]+y_e[:-1]) ) , data , np.vstack([x,y]).T , method = "splinef2d", bounds_error = False)
    z[np.where(np.isnan(z))] = 0.0
    if sort :
        idx = z.argsort()
        x, y, z = x[idx], y[idx], z[idx]
    return x,y,z

cmap="Spectral_r"
fig, (ax1,ax2) = plt.subplots(1, 2,figsize=(20,10))

blue=np.array([32,81,159])/255
red=np.array([193,78,160])/255

ax1.set_xlim(-1,15)
ax1.set_ylim(-3,25)
x=Ch7
y=Ch11#/(Ch7+1)
#ax1.set_aspect('equal', adjustable='box')
x,y,z=density_scatter( x , y, sort = False, bins =[40,40])
ax1.scatter(x,y,color=blue,s=1,cmap=cmap)
norm = Normalize(vmin = np.min(z), vmax = np.max(z))
ymin, ymax = ax1.get_ylim()
xmin, xmax = ax1.get_xlim()
R=np.corrcoef(x,y)[0,1]
rho, pval = spearmanr(x, y)
xs = np.linspace(0.0, 1.0, 100)
rgb1 = cm.get_cmap(cmap)(xs)[0][:-1]
rgb2 = cm.get_cmap(cmap)(xs)[-1][:-1]
rgb=[rgb1,rgb2][np.argmax([sum(rgb2),sum(rgb1)])]  #These lines are just to get the color of the x=y line and the correlation values match the colormap
ax1.text(xmax-0.3*abs(xmax-xmin),ymax+2-0.14*abs(ymax-ymin),horizontalalignment='left',verticalalignment='top',s="R-value: "+str(round(R,3)),color=rgb)
ax1.text(xmax-0.3*abs(xmax-xmin),ymax+2-0.1*abs(ymax-ymin),horizontalalignment='left',verticalalignment='top',s=r'$\rho$: '+str(round(rho,3)),color=rgb)
ax1.scatter(x[cones_ID],y[cones_ID],color=red,s=20,cmap=cmap)
ax1.set_xlabel("Ch7 (DNA stain)")
ax1.set_ylabel("Ch11 (Photoreceptor stain)")
ax1.set_title("Uncompensated")

ax2.set_xlim(-1,15)
ax2.set_ylim(-5,25)
x=Ch7
y=Ch11-(Ch7)
#ax2.set_aspect('equal', adjustable='box')
x,y,z=density_scatter( x , y, sort = False, bins =[40,40])
ax2.scatter(x,y,color=blue,s=1,cmap=cmap)
norm = Normalize(vmin = np.min(z), vmax = np.max(z))
ymin, ymax = ax2.get_ylim()
xmin, xmax = ax2.get_xlim()
R=np.corrcoef(x,y)[0,1]
rho, pval = spearmanr(x, y)
xs = np.linspace(0.0, 1.0, 100)
rgb1 = cm.get_cmap(cmap)(xs)[0][:-1]
rgb2 = cm.get_cmap(cmap)(xs)[-1][:-1]
rgb=[rgb1,rgb2][np.argmax([sum(rgb2),sum(rgb1)])]  #These lines are just to get the color of the x=y line and the correlation values match the colormap
ax2.text(xmax-0.3*abs(xmax-xmin),ymax+2-0.14*abs(ymax-ymin),horizontalalignment='left',verticalalignment='top',s="R-value: "+str(round(R,3)),color=rgb)
ax2.text(xmax-0.3*abs(xmax-xmin),ymax+2-0.1*abs(ymax-ymin),horizontalalignment='left',verticalalignment='top',s=r'$\rho$: '+str(round(rho,3)),color=rgb)
ax2.scatter(x[cones_ID],y[cones_ID],color=red,s=20,cmap=cmap)
ax2.set_xlabel("Ch7 (DNA stain)")
ax2.set_ylabel("Ch11 (Photoreceptor stain)")
ax2.set_title("Compensation by substracting Ch7 from Ch11")



#plt.savefig("compensations.png",bbox_inches="tight",dpi=200)

# %%
x[cones_ID]

# %%
sum(y>0)/len(y)

# %%
cones1=[7868, 53328, 8687, 7995, 9260, 6729, 8915, 52667, 54913, 7653, 9375, 51527, 52213, 50763, 49827, 52724, 9536, 7142, 55078, 54239, 55344, 5515, 52102, 5603, 55535, 730, 8570, 5234, 6892, 784, 7346, 7347, 9290, 53041, 53200, 49940, 52738, 7048, 5737, 841, 6597, 7316, 55102, 5508]
cones2=[6491, 8093, 53796, 7800, 7261, 5622, 939, 6541, 52091, 7346, 49940, 7868, 54170, 8915, 53041, 52738, 863, 5978, 8199, 7048, 7316]
cones=cones1+cones2
DATASET="Retina_1_2"
basepath = r"C:\Users\Thibaut Goldsborough\Documents\Seth_BoneMarrow\Data\\" +DATASET
outpath = basepath + "\\Outputs"

df=pd.read_csv(outpath+"\\cell_info1.csv")

Ch7=df["Scaled_Ch07"].to_numpy()#[:,None]
Ch10=df["Scaled_Ch10"].to_numpy()#[:,None]
Ch11=df["Scaled_Ch11"].to_numpy()#[:,None]

from Helper_functions import density_scatter
from scipy.stats import spearmanr
from matplotlib import cm
from matplotlib.colors import Normalize 
from scipy.interpolate import interpn

def density_scatter( x , y, sort = True, bins = 20 )   :
    data , x_e, y_e = np.histogram2d( x, y, bins = bins, density = True )
    z = interpn( ( 0.5*(x_e[1:] + x_e[:-1]) , 0.5*(y_e[1:]+y_e[:-1]) ) , data , np.vstack([x,y]).T , method = "splinef2d", bounds_error = False)
    z[np.where(np.isnan(z))] = 0.0
    if sort :
        idx = z.argsort()
        x, y, z = x[idx], y[idx], z[idx]
    return x,y,z

cmap="Spectral_r"

x=Ch7
y=Ch11#/(Ch7+1)
#

fig, (ax1) = plt.subplots(1, 1,figsize=(20,7))

#ax1.set_xlim(1,15)
#ax1.set_ylim(0,5)
ax1.set_aspect('equal', adjustable='box')
#np.random.shuffle(x)
#np.random.shuffle(y)

x,y,z=density_scatter( x , y, sort = False, bins =[40,40])
ax1.scatter(x,y,c=z,s=1,cmap=cmap)
norm = Normalize(vmin = np.min(z), vmax = np.max(z))
    
ymin, ymax = ax1.get_ylim()
xmin, xmax = ax1.get_xlim()
R=np.corrcoef(x,y)[0,1]
rho, pval = spearmanr(x, y)
xs = np.linspace(0.0, 1.0, 100)
rgb1 = cm.get_cmap(cmap)(xs)[0][:-1]
rgb2 = cm.get_cmap(cmap)(xs)[-1][:-1]
rgb=[rgb1,rgb2][np.argmax([sum(rgb2),sum(rgb1)])]  #These lines are just to get the color of the x=y line and the correlation values match the colormap

ax1.text(xmax-0.2*abs(xmax-xmin),ymin+0.14*abs(ymax-ymin),horizontalalignment='left',verticalalignment='top',s="R-value: "+str(round(R,3)),color=rgb)
ax1.text(xmax-0.2*abs(xmax-xmin),ymin+0.1*abs(ymax-ymin),horizontalalignment='left',verticalalignment='top',s=r'$\rho$: '+str(round(rho,3)),color=rgb)
#axs[i].text(ymin+0.1*abs(ymax-ymin),ymax-0.16*abs(ymax-ymin),horizontalalignment='left',verticalalignment='top',s="p-value: "+str(pval),color='red')
#xy=np.linspace(ymin,ymax,100)
#ax1.plot(xy,xy,color=rgb)

ax1.set_xlabel("Ch7")
ax1.set_ylabel("Ch10")
ax1.set_title("Title")

# %%
from Helper_functions import load_dict
import cv2 as cv
from Helper_functions import interactive_session
namesdf=df["Cell_ID"].to_numpy()
image_dict=load_dict(outpath,namesdf,64)
display_images=[image_dict[int(i)]['Ch1'] for i in namesdf]
display_images-=np.min(display_images)
display_images/=np.max(display_images)
display_images*=255
display_images*=1.5
u=np.vstack((x,y)).T
interactive_session(u,display_images,z,namesdf)

# %%
plt.hist(Ch7,bins=300);

# %%
cones1=[7868, 53328, 8687, 7995, 9260, 6729, 8915, 52667, 54913, 7653, 9375, 51527, 52213, 50763, 49827, 52724, 9536, 7142, 55078, 54239, 55344, 5515, 52102, 5603, 55535, 730, 8570, 5234, 6892, 784, 7346, 7347, 9290, 53041, 53200, 49940, 52738, 7048, 5737, 841, 6597, 7316, 55102, 5508]
cones2=[6491, 8093, 53796, 7800, 7261, 5622, 939, 6541, 52091, 7346, 49940, 7868, 54170, 8915, 53041, 52738, 863, 5978, 8199, 7048, 7316]
cones=cones1+cones2

# %%
len(np.unique(cones1+cones2))
print(len(cones))

# %%
plt.imshow(display_images[np.where(namesdf==cones[10])][0])

# %%
np.where(namesdf in np.array(cones).any())

# %%
DATASET="BoneMarrow_sample1"

basepath = r"C:\Users\Thibaut Goldsborough\Documents\Seth_BoneMarrow\Data\\" +DATASET
outpath = basepath + "\\Outputs"

df=pd.read_csv(outpath+"\\cell_info1.csv")

Ch=list(df["DNA_pos"].to_numpy())
Ch7=df["Scaled_Ch07"].to_numpy()

GR=df["Gradient RMS_M01_Ch01"].to_numpy()
print(sum(GR>50)/len(GR))

DNA_pos=Ch7>1.8

df["DNA_pos"]=DNA_pos
#df.to_csv(outpath+"\\"+""+"cell_info1.csv",index=False)

plt.hist(Ch7,bins=300);
plt.xlim(2,3.5)

print(sum(Ch)/len(Ch))
plt.show()
print(sum(Ch7>1.8)/len(Ch7))

# %%
plt.hist(GR,bins=300);

# %%
sum(Ch)/len(Ch)

# %%
sum(Ch7>1)/len(Ch7)
